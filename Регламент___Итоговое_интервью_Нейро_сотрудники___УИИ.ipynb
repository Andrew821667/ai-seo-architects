# %% [markdown]
# <h1><b><center>Регламент сдачи интервью</center></b></h1>
# <hr>
# <h3>Билет состоит из 4 вопросов</h3>
# <ol>
# <li> Вопрос по Python </li>
# <li> Вопрос по GPT </li>
# <li> Вопрос по GPT </li>
# <li> Разбор примера решения задачи
# </ol>
#
# <h5> На каждый вопрос участнику дается 6 минут времени: 4 - на ответ, 2 - на дополнительные вопросы (если есть необходимость) </h5>
# <h5> Каждый ответ оценивается по 5-ти бальной шкале.</h5>
# <h5> Возможны дополнительные вопросы от интервьюера для уточнения.</h5>
# <ul> <font size="2">Критерии оценивания вопросов по Python и GPT:
# <li> <b>5 баллов:</b> даны полноценные ответы на вопрос билета. </li>
# <li> <b>4 балла:</b> даны ответы на все вопросы, но с помощью (подсказками, наводками) интервьюера </li>
# <li> <b>3 балла:</b> ответ на вопрос билета раскрыт не полностью, допущены ошибки в ответах на дополнительные вопросы </li>
# <li> <b>2 балла:</b> ответ на вопрос билета дан поверхностно, дан ответ только на 1 дополнительный вопрос </li>
# <li> <b>1 балл:</b> нет ответа на вопрос билета, но есть хотя бы минимальные ответы на дополнительные вопросы </li>
# </font></ul>
# <ul> <font size="2">Критерии оценивания Разбор примера решения задачи:
# <li> <b>5 баллов:</b> даны полноценные ответы по заданию </li>
# <li> <b>4 балла:</b> при ответе допущена незначительная ошибка </li>
# <li> <b>3 балла:</b> ответ раскрыт не полностью, допущена значительная ошибка при ответе </li>
# <li> <b>2 балла:</b> ответ дан поверхностно, не раскрыт, допущено много ошибок при ответе </li>
# <li> <b>1 балл:</b> задание не выполнено, но прослеживается правильный ход мысли </li>
# </font></ul>
#
#
# <h3> Финальная оценка за интервью </h3>
# <ul> <font size="2"> Финальная оценка за интервью формируется на основе суммы полученных баллов за 4 вопроса билета.
# <li> <b>Оценка 5:</b> 18-20 баллов</li>
# <li> <b>Оценка 4:</b> 15-17 баллов</li>
# <li> <b>Пересдача:</b> менее 15 баллов</li>

# %% [markdown]
# <h1> <center> <b> Список вопросов </b> </center></h1>
# <hr>
# <ol><font size="2"><h4> Python </h4>
# <li>Функции ввода/вывода данных Python (print(), input()).</li>
# <li>Арифметические операции, переменные, типы данных.</li>
# <li>Логические условия и условный оператор.</li>
# <li>Циклы for и while.</li>
# <li>Списки, кортежи, словари.</li>
# <li>Функции в Python. Встроенные и пользовательские.</li>
# <li>Работа с текстами. Операции над строками. Методы строк.</li>
# <li>Генераторы. Генератор списка, словаря.</li>
# <li>Модули и библиотеки. Модуль re. Модуль os.</li>
# <li>Самостоятельно написанные модули. Функция open(). Контекстный менеджер with.</li>
# <li>Замыкания и декораторы.</li>
# <li>Библиотека Pandas. Базовые методы.</li>
# </font></ol>
# <ol><font size="2"><h4> GPT </h4>
# <li>Роли в ChatGPT, их влияние на результат.</li>
# <li>Модели ChatGPT. Отличия моделей.</li>
# <li>Сплитеры и их отличия.</li>
# <li>База знаний. Источники базы знаний.</li>
# <li>Обработка информации из различных источников.</li>
# <li>Создание диалога. </li>
# <li>Использование нескольких моделей ChatGPT.</li>
# <li>Парсинг сайтов. Методы обработки страниц.</li>
# <li>Асинхронное программирование.</li>
# <li>Принципы написания эффективных инструкций для моделей GPT.</li>
# <li>Методы оптимизации количества токенов.</li>
# <br>
# <li>Основы промпт инжиниринга. Zero-shot, Few-shot и Chain-of-thought подходы.</li>
# <li>Векторная база. Создание и использование.</li>
# <li>Методы распознавания и синтеза речи.</li>
# <li>Нейро-копирайтер по видео.</li>
# <li>Нейро-контроль качества отдела продаж.</li>
# <li>Нейро-HR для проведения собеседований.</li>
#
# <li>Нейро-продажник.</li>
# <li>Нейро-продажник в телефонных звонках. </li>
# <li>Нейро-тех.поддержка.</li>
#
# <li>Библиотеки для создания сложных сценариев. </li>
# <li>Работа с базами данных (SQL).</li>
#
# </font></ol>

# %% [markdown]
# **Разбор примера решения задачи**
#
#
# *Пример*
#
# ```
# 1. Внимательно рассмотрите код, написанный ниже (код из материалов УИИ).
# 2. Для каждой строки опишите операцию, которая в ней выполняется.
# 3. Дополните функцию ...
# 4. Для решения какой задачи может быть использован данный фрагмент кода?
#
# ```
